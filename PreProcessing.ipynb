# %%
import os
import numpy as np
import pandas as pd

# %%
music1 = pd.read_csv('spotifytoptracks.csv')

# %%
music1.shape
# Out:
# (50, 17)

# %%
music1.head(10)
# Out:
#    Unnamed: 0         artist                                    album  \
# 0           0     The Weeknd                              After Hours
# 1           1    Tones And I                             Dance Monkey
# 2           2    Roddy Ricch    Please Excuse Me For Being Antisocial
# 3           3      SAINt JHN                    Roses (Imanbek Remix)
# 4           4       Dua Lipa                         Future Nostalgia
# 5           5         DaBaby                         BLAME IT ON BABY
# 6           6   Harry Styles                                Fine Line
# 7           7          Powfu         death bed (coffee for your head)
# 8           8  Trevor Daniel                                 Nicotine
# 9           9  Lewis Capaldi  Divinely Uninspired To A Hellish Extent
#
#                          track_name                track_id  energy  \
# 0                   Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730
# ...

# %%
#to make data analysis easy
music1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   artist            50 non-null     object
#  2   album             50 non-null     object
#  3   track_name        50 non-null     object
#  4   track_id          50 non-null     object
#  5   energy            50 non-null     float64
#  6   danceability      50 non-null     float64
#  7   key               50 non-null     int64
#  8   loudness          50 non-null     float64
#  9   acousticness      50 non-null     float64
#  10  speechiness       50 non-null     float64
#  11  instrumentalness  50 non-null     float64
#  12  liveness          50 non-null     float64
#  13  valence           50 non-null     float64
#  14  tempo             50 non-null     float64
#  15  duration_ms       50 non-null     int64
# ...

# %%
#fetching the useful data from the data set to work on.
music1[['key','album','track_name','artist','track_id','valence','liveness','loudness','danceability','genre']]
# Out:
#     key                                              album  \
# 0     1                                        After Hours
# 1     6                                       Dance Monkey
# 2    10              Please Excuse Me For Being Antisocial
# 3     8                              Roses (Imanbek Remix)
# 4    11                                   Future Nostalgia
# 5    11                                   BLAME IT ON BABY
# 6     0                                          Fine Line
# 7     8                   death bed (coffee for your head)
# 8    10                                           Nicotine
# 9     1            Divinely Uninspired To A Hellish Extent
# 10    2                                               Tusa
# 11    6                                            ROXANNE
# 12    0                               Hollywood's Bleeding
# 13    0                                 Certified Hitmaker
# 14    9                                            Changes
# ...

# %%
#checking for null values
music1.isnull().sum()
# Out:
# Unnamed: 0          0
# artist              0
# album               0
# track_name          0
# track_id            0
# energy              0
# danceability        0
# key                 0
# loudness            0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# genre               0
# dtype: int64

# %%
#checking for duplicated data
music1.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Renaming few columns
musics = music1.rename(columns={
    'key': 'Key', 
    'track_name': 'Track Name', 
    'artist': 'Artist', 'track_id':'Track ID', 'genre':'Genre'
})
print("\nRenamed Columns:")
print(music1.head())
# Out:
# Renamed Columns:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
# 3           3    SAINt JHN                  Roses (Imanbek Remix)
# 4           4     Dua Lipa                       Future Nostalgia
#
#               track_name                track_id  energy  danceability  key  \
# 0        Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2                The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
# 3  Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8
# 4        Don't Start Now  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# ...

# %%
music1.head()
# Out:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
# 3           3    SAINt JHN                  Roses (Imanbek Remix)
# 4           4     Dua Lipa                       Future Nostalgia
#
#               track_name                track_id  energy  danceability  key  \
# 0        Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2                The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
# 3  Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8
# 4        Don't Start Now  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# ...
